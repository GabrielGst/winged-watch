# %%
# import xarray as xr

# ds = xr.open_dataset("./bdd/arome__001__HP1__00H__2024-11-07T09_00_00Z.grib2", engine="cfgrib")

# for v in ds:
#     print("{}, {}, {}".format(v, ds[v].attrs["long_name"], ds[v].attrs["units"]))
    
import cfgrib
import pandas

# Load all layers, separated into individual datasets
datasets = cfgrib.open_datasets("./arome__0025__SP1__00H06H__2024-11-07T21_00_00Z.grib2")

# Print information about each dataset
# for i, ds in enumerate(datasets):
#     print(f"Dataset {i}:")
#     print("\n")
#     print(ds)
#     print("\n")
#     print("Next:\n")


wind_speed = datasets[1].si10
wind_direction = datasets[1].wdir10

# print(wind_speed)
# print(wind_direction)

# df = wind_direction.to_dataframe()
# df["wdir10"] = df["wdir10"].fillna(0)


df2 = wind_speed.to_dataframe()
df2["si10"] = df2["si10"].fillna(0)

# df = df.reset_index()
df = df2.reset_index()

# # Extract lon and lat from "index" column using regex
# df[["lon", "lat"]] = df["index"][1], df["index"][2] 

# # Convert lon and lat columns to float type (optional, based on your requirements)
# df["lon"] = df["lon"].astype(float)
# df["lat"] = df["lat"].astype(float)

df["longitude"] = df["longitude"].astype('float64')
df["latitude"] = df["latitude"].astype('float64')

df_morbihan = df.loc[(df["longitude"] > -3) & (df["longitude"] < -2.5) & (df["latitude"] > 47) & (df["latitude"] < 47.7)]

df_morbihan.head(10).style

import plotly.express as px

fig = px.scatter_geo(
    df_morbihan,
    lat="latitude",
    lon="longitude",
    size="si10", # size of markers, "pop" is one of the columns of gapminder
    color="valid_time"
)

fig.show()

# df.to_csv("wind_direction.csv", index=False)

# df2.to_csv("wind_speed.csv", index=False)
# Out:
# Ignoring index file './arome__0025__SP1__00H06H__2024-11-07T21_00_00Z.grib2.5b7b6.idx' incompatible with GRIB file
# Ignoring index file './arome__0025__SP1__00H06H__2024-11-07T21_00_00Z.grib2.5b7b6.idx' incompatible with GRIB file
# Ignoring index file './arome__0025__SP1__00H06H__2024-11-07T21_00_00Z.grib2.5b7b6.idx' incompatible with GRIB file
# Ignoring index file './arome__0025__SP1__00H06H__2024-11-07T21_00_00Z.grib2.5b7b6.idx' incompatible with GRIB file
# Ignoring index file './arome__0025__SP1__00H06H__2024-11-07T21_00_00Z.grib2.5b7b6.idx' incompatible with GRIB file
# Ignoring index file './arome__0025__SP1__00H06H__2024-11-07T21_00_00Z.grib2.5b7b6.idx' incompatible with GRIB file
# Ignoring index file './arome__0025__SP1__00H06H__2024-11-07T21_00_00Z.grib2.5b7b6.idx' incompatible with GRIB file
# Ignoring index file './arome__0025__SP1__00H06H__2024-11-07T21_00_00Z.grib2.5b7b6.idx' incompatible with GRIB file
# ...
